# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from math import *

# %% [markdown]
# # Wczytywanie Danych!

# %%
# %store -r df2
df = df2.copy()

# %%
df
# Out:
#          date>gold_price
# 60   2016-01-01>1095.655
# 61   2016-02-01>1194.893
# 62   2016-03-01>1246.312
# 63   2016-04-01>1241.452
# 64   2016-05-01>1259.755
# 65    2016-06-01>1273.58
# 66   2016-07-01>1337.429
# 67   2016-08-01>1340.861
# 68   2016-09-01>1326.618
# 69   2016-10-01>1268.929
# 70   2016-11-01>1240.293
# 71   2016-12-01>1152.165
# 72   2017-01-01>1192.648
# 73    2017-02-01>1233.39
# 74   2017-03-01>1231.063
# 75    2017-04-01>1267.15
# 76    2017-05-01>1245.25
# 77   2017-06-01>1261.277
# 78     2017-07-01>1235.1
# 79    2017-08-01>1281.72
# 80   2017-09-01>1317.045
# 81   2017-10-01>1280.677
# 82   2017-11-01>1283.189
# 83   2017-12-01>1265.674
# 84   2018-01-01>1332.809
# 85   2018-02-01>1333.775
# 86   2018-03-01>1325.562
# 87   2018-04-01>1335.332
# 88   2018-05-01>1303.618
# 89   2018-06-01>1282.126
# 90   2018-07-01>1238.064
# 91   2018-08-01>1201.859
# 92   2018-09-01>1199.198
# 93   2018-10-01>1214.726
# 94   2018-11-01>1221.275
# 95   2018-12-01>1249.887
# 96    2019-01-01>1291.63
# 97   2019-02-01>1319.755
# 98   2019-03-01>1302.286
# 99    2019-04-01>1287.65
# 100   2019-05-01>1282.46
# 101  2019-06-01>1358.488
# 102  2019-07-01>1414.611
# 103  2019-08-01>1497.102
# 104  2019-09-01>1510.336
# 105  2019-10-01>1494.765
# 106  2019-11-01>1471.921
# 107  2019-12-01>1480.025
# 108  2020-01-01>1560.668
# 109  2020-02-01>1598.818
# 110  2020-03-01>1593.764
# 111   2020-04-01>1680.03
# 112  2020-05-01>1715.697
# 113  2020-06-01>1734.032
# 114  2020-07-01>1840.807
# 115   2020-08-01>1968.63
# 116   2020-09-01>1921.92
# 117   2020-10-01>1900.27
# 118    2020-11-01>1866.3
# 119   2020-12-01>1858.42

# %% [markdown]
# # Data Cleaning!

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 60 to 119
# Data columns (total 1 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date>gold_price  60 non-null     object
# dtypes: object(1)
# memory usage: 612.0+ bytes

# %%
df = df["date>gold_price"].str.split('>', expand=True)

# %%
df
# Out:
#               0         1
# 60   2016-01-01  1095.655
# 61   2016-02-01  1194.893
# 62   2016-03-01  1246.312
# 63   2016-04-01  1241.452
# 64   2016-05-01  1259.755
# 65   2016-06-01   1273.58
# 66   2016-07-01  1337.429
# 67   2016-08-01  1340.861
# 68   2016-09-01  1326.618
# 69   2016-10-01  1268.929
# 70   2016-11-01  1240.293
# 71   2016-12-01  1152.165
# 72   2017-01-01  1192.648
# 73   2017-02-01   1233.39
# 74   2017-03-01  1231.063
# 75   2017-04-01   1267.15
# 76   2017-05-01   1245.25
# 77   2017-06-01  1261.277
# 78   2017-07-01    1235.1
# 79   2017-08-01   1281.72
# 80   2017-09-01  1317.045
# 81   2017-10-01  1280.677
# 82   2017-11-01  1283.189
# 83   2017-12-01  1265.674
# 84   2018-01-01  1332.809
# 85   2018-02-01  1333.775
# 86   2018-03-01  1325.562
# 87   2018-04-01  1335.332
# 88   2018-05-01  1303.618
# 89   2018-06-01  1282.126
# 90   2018-07-01  1238.064
# 91   2018-08-01  1201.859
# 92   2018-09-01  1199.198
# 93   2018-10-01  1214.726
# 94   2018-11-01  1221.275
# 95   2018-12-01  1249.887
# 96   2019-01-01   1291.63
# 97   2019-02-01  1319.755
# 98   2019-03-01  1302.286
# 99   2019-04-01   1287.65
# 100  2019-05-01   1282.46
# 101  2019-06-01  1358.488
# 102  2019-07-01  1414.611
# 103  2019-08-01  1497.102
# 104  2019-09-01  1510.336
# 105  2019-10-01  1494.765
# 106  2019-11-01  1471.921
# 107  2019-12-01  1480.025
# 108  2020-01-01  1560.668
# 109  2020-02-01  1598.818
# 110  2020-03-01  1593.764
# 111  2020-04-01   1680.03
# 112  2020-05-01  1715.697
# 113  2020-06-01  1734.032
# 114  2020-07-01  1840.807
# 115  2020-08-01   1968.63
# 116  2020-09-01   1921.92
# 117  2020-10-01   1900.27
# 118  2020-11-01    1866.3
# 119  2020-12-01   1858.42

# %%
df.columns = ["Date","Price"]

# %%
df[["Year","Month","Day"]] = df["Date"].str.split("-",expand=True)
df = df.drop(columns=["Date"])

# %%
df = df.drop(columns=["Day"])
df = df[["Year","Month","Price"]]
df
# Out:
#      Year Month     Price
# 60   2016    01  1095.655
# 61   2016    02  1194.893
# 62   2016    03  1246.312
# 63   2016    04  1241.452
# 64   2016    05  1259.755
# 65   2016    06   1273.58
# 66   2016    07  1337.429
# 67   2016    08  1340.861
# 68   2016    09  1326.618
# 69   2016    10  1268.929
# 70   2016    11  1240.293
# 71   2016    12  1152.165
# 72   2017    01  1192.648
# 73   2017    02   1233.39
# 74   2017    03  1231.063
# 75   2017    04   1267.15
# 76   2017    05   1245.25
# 77   2017    06  1261.277
# 78   2017    07    1235.1
# 79   2017    08   1281.72
# 80   2017    09  1317.045
# 81   2017    10  1280.677
# 82   2017    11  1283.189
# 83   2017    12  1265.674
# 84   2018    01  1332.809
# 85   2018    02  1333.775
# 86   2018    03  1325.562
# 87   2018    04  1335.332
# 88   2018    05  1303.618
# 89   2018    06  1282.126
# 90   2018    07  1238.064
# 91   2018    08  1201.859
# 92   2018    09  1199.198
# 93   2018    10  1214.726
# 94   2018    11  1221.275
# 95   2018    12  1249.887
# 96   2019    01   1291.63
# 97   2019    02  1319.755
# 98   2019    03  1302.286
# 99   2019    04   1287.65
# 100  2019    05   1282.46
# 101  2019    06  1358.488
# 102  2019    07  1414.611
# 103  2019    08  1497.102
# 104  2019    09  1510.336
# 105  2019    10  1494.765
# 106  2019    11  1471.921
# 107  2019    12  1480.025
# 108  2020    01  1560.668
# 109  2020    02  1598.818
# 110  2020    03  1593.764
# 111  2020    04   1680.03
# 112  2020    05  1715.697
# 113  2020    06  1734.032
# 114  2020    07  1840.807
# 115  2020    08   1968.63
# 116  2020    09   1921.92
# 117  2020    10   1900.27
# 118  2020    11    1866.3
# 119  2020    12   1858.42

# %%
df.dtypes # Trzeba zmienić typy danych
# Out:
# Year     object
# Month    object
# Price    object
# dtype: object

# %%
df = df.astype({"Year": int, "Month": int,"Price": float})
df.dtypes
# Out:
# Year       int64
# Month      int64
# Price    float64
# dtype: object

# %% [markdown]
# # Informacje

# %% [markdown]
# ## Podstawowe informacje

# %%
df.describe()
# Out:
#               Year      Month        Price
# count    60.000000  60.000000    60.000000
# mean   2018.000000   6.500000  1387.679017
# std       1.426148   3.481184   216.918213
# min    2016.000000   1.000000  1095.655000
# 25%    2017.000000   3.750000  1246.046500
# 50%    2018.000000   6.500000  1296.958000
# 75%    2019.000000   9.250000  1483.710000
# max    2020.000000  12.000000  1968.630000

# %% [markdown]
# ## Zwracamy największą wartość w zwiorze wartości

# %%
# Max
df[df["Price"] == df["Price"].max()]
maxPrice = float(df[df["Price"] == df["Price"].max()]["Price"])
print(df[df["Price"] == df["Price"].max()],"--->" ,maxPrice)
# Out:
#      Year  Month    Price
# 115  2020      8  1968.63 ---> 1968.63

# %% [markdown]
# ## Zwracamy najmniejszą wartość w zwiorze wartości

# %%
# Min
df[df["Price"] == df["Price"].min()]
minPrice = float(df[df["Price"] == df["Price"].min()]["Price"])
print(df[df["Price"] == df["Price"].min()],"--->" ,minPrice)
# Out:
#     Year  Month     Price
# 60  2016      1  1095.655 ---> 1095.655

# %% [markdown]
# ## Różnica między największą wartością a najmniejszą wartością

# %%
# Rozstęp
rozstep = maxPrice - minPrice
print(rozstep)
# Out:
# 872.9750000000001

# %% [markdown]
# ## Ilość wartości

# %%
n = len(df)
n
# Out:
# 60

# %% [markdown]
# ## Pierwiastek z ilości wartości

# %%
k = sqrt(n)
k
# Out:
# 7.745966692414834

# %% [markdown]
# ## Zaokrąglona wartość rozstępu przez k

# %%
szerokosc = round(rozstep/k)
szerokosc
# Out:
# 113

# %% [markdown]
# ## Grupowanie wartości
#
# ### Tworzymy dwie listy: "początek", "koniec"
# ### początek to [minPrice, minPrice + szerokość, minPrice + 2*szerokość, minPrice 3*szerokość,...]
# ### koniec to [poczatek[0] + szerokość, poczatek[1] + szerokość, poczatek[2] + szerokość, poczatek[3] + szerokość,...]

# %%
# Początek
# Koniec

początek = [minPrice]
koniec = []
a = minPrice
i = 0
while i <8:
    a += szerokosc
    koniec.append(a)
    początek.append(a)
    i+=1
początek.pop()
print("Początek: ", początek, "oraz Koniec: " , koniec)
# Out:
# Początek:  [1095.655, 1208.655, 1321.655, 1434.655, 1547.655, 1660.655, 1773.655, 1886.655] oraz Koniec:  [1208.655, 1321.655, 1434.655, 1547.655, 1660.655, 1773.655, 1886.655, 1999.655]

# %% [markdown]
# ## Liczymy ile wartości z zbioru wartości jest mniejszych niż dana wartość z listy "koniec"

# %%
# n_i cum
pierwszy_element = len(df[df["Price"] < 1160.317])

n_i_cum = [pierwszy_element]
i = 0
b = 1160.317
liczba_elementów = 0
while i < len(koniec):
    b += szerokosc
    liczba_elementów = len(df[df["Price"] < b])
    n_i_cum.append(liczba_elementów)
    i +=1
    if len(n_i_cum) >= 9:
        n_i_cum.pop()
print(n_i_cum)
# Out:
# [2, 22, 42, 47, 51, 53, 54, 59]

# %% [markdown]
# ## Różnica miedzy ilością wartości w n_i_cum[i] od n_i_cum[i-1]

# %%
# n_i
pierwszy_element = n_i_cum[0]  # element zerowy (pierwszy w liscie n_i_cum) nie możemy odjąć od poprzedniego, wieć przepisujemy wartość n_i_cum[0]
n_i = [pierwszy_element]
element = 0
i = 1
while i < len(n_i_cum):
    element = n_i_cum[(i)] - n_i_cum[i-1]
    n_i.append(element)
    i+=1
    if len(n_i) >= 9:
        n_i.pop()
print(n_i)
# Out:
# [2, 20, 20, 5, 4, 2, 1, 5]

# %%
g7 = pd.DataFrame({
    "Początek":początek,
    "Koniec":koniec,
    "n_i cum":n_i_cum,
    "n_i":n_i
})
g7
# Out:
#    Początek    Koniec  n_i cum  n_i
# 0  1095.655  1208.655        2    2
# 1  1208.655  1321.655       22   20
# 2  1321.655  1434.655       42   20
# 3  1434.655  1547.655       47    5
# 4  1547.655  1660.655       51    4
# 5  1660.655  1773.655       53    2
# 6  1773.655  1886.655       54    1
# 7  1886.655  1999.655       59    5

# %%
x = np.arange(0,7)
xlabel = [0]
for element in początek:
    xlabel.append(element)
plt.figure(figsize=(12,6))

plt.plot(g7["n_i"],color="red",marker="o",markersize=7)
plt.legend("n_i")

# %store g7 początek
# Out:
# Stored 'g7' (DataFrame)
# Stored 'początek' (list)

# %% [markdown]
# # Dalsze Obliczenia

# %% [markdown]
# ## Środek czyli (początek[i]+koniec[i])/2

# %%
# środek
pierwszy_element = (początek[0]+koniec[0])/2
srodek = []
i = 0
element = 0
while i < len(koniec):
    element = (początek[i]+koniec[i])/2
    srodek.append(element)
    i +=1

print(srodek)
# Out:
# [1152.155, 1265.155, 1378.155, 1491.155, 1604.155, 1717.155, 1830.155, 1943.155]

# %%
# srodek*n_i
pierwszy_element = srodek[0]*n_i[0]
srodek_n_i = []
i = 0 
while i < len(srodek):
    srodek_n_i.append(srodek[i] * n_i[i])
    i+=1

print(srodek_n_i)
# Out:
# [2304.31, 25303.1, 27563.1, 7455.775, 6416.62, 3434.31, 1830.155, 9715.775]

# %%
# srodek - srednia
srodek_srednia = []
i = 0 
while i < len(srodek):
    srodek_srednia.append(srodek[i]-df["Price"].mean())
    i+=1

print(srodek_srednia)
# Out:
# [-235.52401666666674, -122.52401666666674, -9.52401666666674, 103.47598333333326, 216.47598333333326, 329.47598333333326, 442.47598333333326, 555.4759833333333]

# %%
# poprzednie^2
poprzednie_2 = []
i = 0 
while i < len(srodek_srednia):
    poprzednie_2.append(srodek_srednia[i]**2)
    i+=1

print(poprzednie_2)
# Out:
# [55471.56242680031, 15012.134660133628, 90.70689346694583, 10707.279126800262, 46861.85136013358, 108554.4235934669, 195784.9958268002, 308553.56806013355]

# %%
# poprzednie*n_i
poprzednie_n_i = []
i = 0 
while i < len(poprzednie_2):
    poprzednie_n_i.append(poprzednie_2[i] * n_i[i])
    i+=1

print(poprzednie_n_i)
# Out:
# [110943.12485360062, 300242.6932026726, 1814.1378693389165, 53536.39563400131, 187447.40544053432, 217108.8471869338, 195784.9958268002, 1542767.8403006678]

# %%
# srodek*n_i cum
srodek_n_i_cum = [srodek_n_i[0]]

i = 1
while i < len(srodek_n_i):
    srodek_n_i_cum.append(srodek_n_i_cum[i-1] + srodek_n_i[1])
    i+=1

print(srodek_n_i_cum)
# Out:
# [2304.31, 27607.41, 52910.509999999995, 78213.60999999999, 103516.70999999999, 128819.81, 154122.91, 179426.01]

# %%
g6 = pd.DataFrame({
    "Początek":początek,
    "Koniec":koniec,
    "n_i cum":n_i_cum,
    "n_i":n_i,
    "Srodek":srodek,
    "Srodek*n_i":srodek_n_i,
    "srodek-srednia":srodek_srednia,
    "poprzednie ^2":poprzednie_2,
    "poprzednie_n_i":poprzednie_n_i,
    "srodek*n_i_cum":srodek_n_i_cum
})
g6
# Out:
#    Początek    Koniec  n_i cum  n_i    Srodek  Srodek*n_i  srodek-srednia  \
# 0  1095.655  1208.655        2    2  1152.155    2304.310     -235.524017
# 1  1208.655  1321.655       22   20  1265.155   25303.100     -122.524017
# 2  1321.655  1434.655       42   20  1378.155   27563.100       -9.524017
# 3  1434.655  1547.655       47    5  1491.155    7455.775      103.475983
# 4  1547.655  1660.655       51    4  1604.155    6416.620      216.475983
# 5  1660.655  1773.655       53    2  1717.155    3434.310      329.475983
# 6  1773.655  1886.655       54    1  1830.155    1830.155      442.475983
# 7  1886.655  1999.655       59    5  1943.155    9715.775      555.475983
#
#    poprzednie ^2  poprzednie_n_i  srodek*n_i_cum
# 0   55471.562427    1.109431e+05         2304.31
# 1   15012.134660    3.002427e+05        27607.41
# 2      90.706893    1.814138e+03        52910.51
# 3   10707.279127    5.353640e+04        78213.61
# 4   46861.851360    1.874474e+05       103516.71
# 5  108554.423593    2.171088e+05       128819.81
# 6  195784.995827    1.957850e+05       154122.91
# 7  308553.568060    1.542768e+06       179426.01

# %% [markdown]
# # STATYSTYKA

# %%
import statistics as st

# %%
# średnia

srednia = df["Price"].mean()
srednia
# Out:
# 1387.6790166666667

# %% [markdown]
# ## Kwartyle
#
# ### Kwartyle dzielą wszystkie obserowowane dane na równe dane co do ilości obserwacji grupy

# %% [markdown]
# ## Kwartyl pierwszy Q1  dzieli dane w stosunku 25% do 75%
# ### 25% danych jest niższa bądź równa wartości Q1, a 75% powyżej bądź równa Q1

# %%
# Kwartyl 1

kwartyl1 = np.percentile(df["Price"], 25) #Q1
kwartyl1
# Out:
# 1246.0465

# %% [markdown]
# ## Kwartyl drugi/Mediana dzieli dane w stosunku 50% do 50%
# ### 50% danych jest niższa bądź równa wartości Q2, a 50% powyżej bądź równa Q2

# %%
# Mediana

mediana = np.percentile(df["Price"], 50) #Mediana
mediana
# Out:
# 1296.958

# %% [markdown]
# ## Kwartyl pierwszy Q3 dzieli dane w stosunku 75% do 25%
# ### 75% danych jest niższa bądź równa wartości Q3, a 25% powyżej bądź równa Q3

# %%
# Kwartyl 3

kwartyl3 = np.percentile(df["Price"], 75) #Q1
kwartyl3
# Out:
# 1483.7100000000003

# %% [markdown]
# ## Dominanta opisuje wartość najczęściej występującą w zbiorze

# %%
# Dominanta
dominanta = 0

if df["Price"].nunique() == len(df.index):
    dominanta = None

# Nie ma dominanty!

# %% [markdown]
# ## Wariancja opisuje jak duże jest zróżnicowanie wyników w danym zbiorze

# %%
# Wariacja

wariacja = np.var(df["Price"])
wariacja
# Out:
# 46269.28597518305

# %% [markdown]
# ## Odchylenie standardowe opisuje czy rozrzut wyników wokół średniej jest niewielki czy wielki.

# %%
# Odchylenie standardowe

odchylenie_standardowe = st.stdev(df["Price"])
odchylenie_standardowe
# Out:
# 216.91821306935734

# %% [markdown]
# ## Rozstęp międzykwartylowy opisuje różnice między Q3 a Q1

# %%
# Rozstęp miedzykwartylowy

rozstęp_miedzykwartylowy = kwartyl3-kwartyl1
rozstęp_miedzykwartylowy
# Out:
# 237.66350000000034

# %% [markdown]
# ## Rozstęp ćwiartkowy opisuje połowe wartości rozstępu miedzykwartylowego

# %%
# Rozstęp ćwiartkowe

odchylenie_cwiartkowe = rozstęp_miedzykwartylowy/2
odchylenie_cwiartkowe
# Out:
# 118.83175000000017

# %% [markdown]
# ## Współczynnik zmienności opisuje zmienność wyników, obserwacji w odniesieniu do wielkości średniej.

# %%
# Klasyczny współczynnik zmienności 

klasyczny_współczynnik_zmienności = (odchylenie_standardowe*100)/srednia
klasyczny_współczynnik_zmienności
# Out:
# 15.631728264538793

# %%
# Pozycyjny współczynnik zmienności

pozycyjny_współczynnik_zmienności = (odchylenie_cwiartkowe*100)/mediana
pozycyjny_współczynnik_zmienności
# Out:
# 9.16234373048319

# %%
# Współczynniki skośności klasyczny

współczynniki_skośności_klasyczny = 3 * ((srednia - mediana)/odchylenie_standardowe)
współczynniki_skośności_klasyczny
# Out:
# 1.254680490627952

# %%
# Kurtoza 
from scipy.stats import kurtosis

kurtoza = kurtosis(df["Price"], fisher=True)
kurtoza
# Out:
# 0.664307825315162

# %%
# Eksces

eksces = kurtoza - 3
eksces
# Out:
# -2.335692174684838

# %% [markdown]
# # Współczynnik konceentraji Giniego

# %% [markdown]
#   1. Współczynnik Giniego przyjmuje wartości [0; 1]
#
#   2. Wartość zerowa mówi o równomierności rozkładu
#
#   3. Wzrost wartości mówi o wzroscie nierówności rozkładu,
#
#   4. Wartość spółczynnika Giniego przyjąłby wartość 1, gdy tylko jedna obserwacja uzyskała dodatnią wartość zmiennej

# %%
# Współczynnik konceentraji Giniego

def gini(dane):
    sorted_list = sorted(dane)

    wzrost, sfera = 0, 0

    for value in sorted_list:

        wzrost += value
        sfera += wzrost - value / 2.
        
    fair_area = wzrost * len(dane) / 2.
    return (fair_area - sfera) / fair_area

wspolczynnik_giniego = gini(df["Price"])
wspolczynnik_giniego
# Out:
# 0.07870517170471346

# %%
statystyka = pd.Series(
    [kwartyl1,mediana,kwartyl3,dominanta,wariacja,odchylenie_standardowe,rozstęp_miedzykwartylowy,odchylenie_cwiartkowe,klasyczny_współczynnik_zmienności,pozycyjny_współczynnik_zmienności,współczynniki_skośności_klasyczny,kurtoza,eksces,wspolczynnik_giniego],
    index=["Kwartyl 1","Mediana","Kwartyl 3","Dominanta","Wariacja","Odchylenie standardowe","Rozstęp miedzykwartylowy","Odchylenie cwiartkowe","Klasyczny współczynnik zmienności","Pozycyjny współczynnik zmienności","Współczynniki skośności klasyczny","Kurtoza","Eksces","Współczynnik Giniego"]
)
statystyka
# Out:
# Kwartyl 1                             1246.046500
# Mediana                               1296.958000
# Kwartyl 3                             1483.710000
# Dominanta                                     NaN
# Wariacja                             46269.285975
# Odchylenie standardowe                 216.918213
# Rozstęp miedzykwartylowy               237.663500
# Odchylenie cwiartkowe                  118.831750
# Klasyczny współczynnik zmienności       15.631728
# Pozycyjny współczynnik zmienności        9.162344
# Współczynniki skośności klasyczny        1.254680
# Kurtoza                                  0.664308
# Eksces                                  -2.335692
# Współczynnik Giniego                     0.078705
# dtype: float64
